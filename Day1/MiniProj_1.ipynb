# %% [markdown]
# <a href="https://colab.research.google.com/github/srilekab2024laiml-lang/Srileka-CodeBooster-2026/blob/main/MiniProj_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/student_performance.csv')

# %%
print(df.head())
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
print("Total number of students:", len(df))
# Out:
# Total number of students: 30

# %%
print("Total number of columns:", len(df.columns))
# Out:
# Total number of columns: 13

# %%
print("Total number of departments:", df['department'].nunique())
# Out:
# Total number of departments: 4

# %%
dept = df.groupby('department').size()
print(dept)
# Out:
# department
# Civil                5
# Computer Science    13
# Electronics          6
# Mechanical           6
# dtype: int64

# %%
print("Highest Maths Score:", df['math_score'].max())
print("Lowest Maths Score:", df['math_score'].min())
print("Average Maths Score:", df['math_score'].mean())
print("Average Programming Score:", df['programming_score'].mean())
print("Average Attendance:", df['attendance_percentage'].mean())
# Out:
# Highest Maths Score: 95
# Lowest Maths Score: 56
# Average Maths Score: 76.06666666666666
# Average Programming Score: 67.6
# Average Attendance: 84.5

# %%
print("\n[4] GENDER-WISE AVERAGE SCORE")
print("-"*40)
gender_scores_analysis = df.groupby('gender')[['math_score', 'science_score', 'english_score', 'programming_score']].mean().round(2)
print(gender_scores_analysis)
# Out:
# [4] GENDER-WISE AVERAGE SCORE
# ----------------------------------------
#         math_score  science_score  english_score  programming_score
# gender
# Female       78.47          81.20          80.80               70.2
# Male         73.67          74.47          67.53               65.0

# %%
print("\n[5] TOP 5 PERFORMANCE")
print("-" * 40)

df['total_score'] = df[['math_score', 'science_score', 'english_score', 'programming_score']].sum(axis=1)
top5 = df.sort_values(by='total_score', ascending=False).head()

for index, row in top5.iterrows():
    print(row['name'], "-", row['total_score'])
# Out:
# [5] TOP 5 PERFORMANCE
# ----------------------------------------
# Ananya Das - 371
# Tanvi Mehta - 367
# Akanksha Yadav - 365
# Arjun Nair - 356
# Divya Singh - 356

# %%
print("Students of Lower Attendance")
print("="*50)
low_at = df[df['attendance_percentage']<75][['name','department','attendance_percentage']]
if len(low_at)>0:
  print(low_at.to_string(index=False))
else:
  print("All the Students are Greater than 75 %")
# Out:
# Students of Lower Attendance
# ...
#          name  department  attendance_percentage
#   Meera Joshi Electronics                     72
#  Rahul Mishra  Mechanical                     68
#  Manoj Pandey       Civil                     65
# Harish Pillai Electronics                     74
#  Sanjay Dubey       Civil                     70
# Sunita Pillai       Civil                     73
